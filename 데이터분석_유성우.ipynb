# %% [markdown]
# # 데이터 가공

# %% [markdown]
# ## 패키지 임포트

# %%
# 넘파이와 판다스 라이브러리 가져오기
import numpy as np
import pandas as pd

# %%
# 데이터셋 불러오기
meteor_showers = pd.read_csv('data/meteorshowers.csv')
constellations = pd.read_csv('data/constellations.csv')
moon_phases = pd.read_csv('data/moonphases.csv')
cities = pd.read_csv('data/cities.csv')

# %%
# 유성우 데이터 확인하기
meteor_showers
# Out:
#            name   radiant bestmonth startmonth  startday  endmonth  endday  \
# 0        Lyrids      Lyra     april      april        21     april      22
# 1  Eta Aquarids  Aquarius       may      april        19       may      28
# 2      Orionids     Orion   october    october         2  november       7
# 3      Perseids   Perseus    august       july        14    august      24
# 4       Leonids       Leo  november   november         6  november      30
#
#            hemisphere preferredhemisphere
# 0            northern            northern
# 1  northern, southern            southern
# 2  northern, southern  northern, southern
# 3            northern            northern
# 4  northern, southern  northern, southern

# %%
# 달의 위상 데이터 확인하기
moon_phases
# Out:
#         month  day      moonphase specialevent
# 0     january    1            NaN          NaN
# 1     january    2  first quarter          NaN
# 2     january    3            NaN          NaN
# 3     january    4            NaN          NaN
# 4     january    5            NaN          NaN
# ..        ...  ...            ...          ...
# 361  december   27            NaN          NaN
# 362  december   28            NaN          NaN
# 363  december   29      full moon          NaN
# 364  december   30            NaN          NaN
# 365  december   31            NaN          NaN
#
# [366 rows x 4 columns]

# %%
moon_phases.info()

# 모든 수치형 컬럼의 통계 요약 (평균, 4분위수 등)
#print(moon_phases.describe())

# 문자열(object) 컬럼에 대한 요약 보고 싶을 때
#print(moon_phases.describe(include='object'))

# (행의 개수, 열의 개수)를 튜플로 반환
#print(moon_phases.shape)

# 컬럼 명칭들을 리스트 형태로 확인
#print(moon_phases.columns)

# 인덱스(행 이름) 범위 확인
#print(moon_phases.index)

# 각 컬럼별 결측치 개수 합산
#print(moon_phases.isnull().sum())

# 마지막 5개 행 확인
#print(moon_phases.tail())

# 무작위로 3개 행 추출 (데이터의 편향을 확인하기 좋음)
#print(moon_phases.sample(3))

# 결측치 비율 확인하기 (실무에서 자주 쓰는 방식)
#missing_ratio = moon_phases.isnull().mean() * 100
#print(f"결측치 비율(%):\n{missing_ratio}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         366 non-null    str
#  1   day           366 non-null    int64
#  2   moonphase     50 non-null     str
#  3   specialevent  10 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 14.5 KB

# %%
# 별자리 데이터 확인하기
constellations
# Out:
#   constellation bestmonth  latitudestart  latitudeend besttime hemisphere
# 0          Lyra    august             90          -40    21:00   northern
# 1      Aquarius   october             65          -90    21:00   southern
# 2         Orion   january             85          -75    21:00   northern
# 3       Perseus  december             90          -35    21:00   northern
# 4           Leo     april             90           65    21:00   northern

# %%
# 도시 데이터 확인하기기
cities
# Out:
#                         city  latitude               country
# 0                  Abu Dhabi     24.47  United Arab Emirates
# 1                      Abuja      9.07               Nigeria
# 2                      Accra      5.55                 Ghana
# 3                  Adamstown    -25.07      Pitcairn Islands
# 4                Addis Ababa      9.02              Ethiopia
# ..                       ...       ...                   ...
# 251  Abidjan(former capital)      6.82           Ivory Coast
# 252                  Yaounde      3.87              Cameroon
# 253          Yaren(de facto)     -0.53                 Nauru
# 254                  Yerevan     40.18               Armenia
# 255                   Zagreb     45.82               Croatia
#
# [256 rows x 3 columns]

# %%
# meteor_showers 유성우 정보 조회
meteor_showers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5 non-null      str
#  1   radiant              5 non-null      str
#  2   bestmonth            5 non-null      str
#  3   startmonth           5 non-null      str
#  4   startday             5 non-null      int64
#  5   endmonth             5 non-null      str
#  6   endday               5 non-null      int64
#  7   hemisphere           5 non-null      str
#  8   preferredhemisphere  5 non-null      str
# dtypes: int64(2), str(7)
# memory usage: 778.0 bytes

# %% [markdown]
# ## 컬럼 dtype 변경(월 이름)

# %%
# 유성우 월 이름 변경
meteor_showers
# Out:
#            name   radiant bestmonth startmonth  startday  endmonth  endday  \
# 0        Lyrids      Lyra     april      april        21     april      22
# 1  Eta Aquarids  Aquarius       may      april        19       may      28
# 2      Orionids     Orion   october    october         2  november       7
# 3      Perseids   Perseus    august       july        14    august      24
# 4       Leonids       Leo  november   november         6  november      30
#
#            hemisphere preferredhemisphere
# 0            northern            northern
# 1  northern, southern            southern
# 2  northern, southern  northern, southern
# 3            northern            northern
# 4  northern, southern  northern, southern

# %%
moon_phases
# Out:
#         month  day      moonphase specialevent
# 0     january    1            NaN          NaN
# 1     january    2  first quarter          NaN
# 2     january    3            NaN          NaN
# 3     january    4            NaN          NaN
# 4     january    5            NaN          NaN
# ..        ...  ...            ...          ...
# 361  december   27            NaN          NaN
# 362  december   28            NaN          NaN
# 363  december   29      full moon          NaN
# 364  december   30            NaN          NaN
# 365  december   31            NaN          NaN
#
# [366 rows x 4 columns]

# %%
moon_phases['month'].unique()
#문페이즈에서 달의 고유값을 뽑아냄
# Out:
# <ArrowStringArray>
# [  'january',  'february',     'march',     'april',       'may',      'june',
#       'july',    'august', 'september',   'october',  'november',  'december']
# Length: 12, dtype: str

# %%
# 월명을 숫자로 변환하기 위한 딕셔너리 생성 months
months = {'january': 1, 
          'february': 2, 
          'march': 3, 
          'april': 4, 
          'may': 5, 
          'june': 6, 
          'july': 7, 
          'august': 8, 
          'september': 9, 
          'october': 10, 
          'november': 11, 
          'december': 12}

# %%
# 유성우데이터프레임의 월명을 숫자로 변환 map 메소드 사용
meteor_showers['bestmonth'].map(months)
# meteor_showers['startmonth'].apply(lambda x: months[x] )
# meteor_showers['endmonth'].replace(months)
# Out:
# 0     4
# 1     5
# 2    10
# 3     8
# 4    11
# Name: bestmonth, dtype: int64

# %%
# 유성우데이터프레임의 월명을 숫자로 변환하고 대입해서 데이터 저장함
meteor_showers['bestmonth'] = meteor_showers['bestmonth'].map(months)

# %%
meteor_showers['startmonth'] = meteor_showers['startmonth'].map(months)
meteor_showers['endmonth'] = meteor_showers['endmonth'].map(months)

# %%
meteor_showers
# Out:
#            name   radiant  bestmonth  startmonth  startday  endmonth  endday  \
# 0        Lyrids      Lyra          4           4        21         4      22
# 1  Eta Aquarids  Aquarius          5           4        19         5      28
# 2      Orionids     Orion         10          10         2        11       7
# 3      Perseids   Perseus          8           7        14         8      24
# 4       Leonids       Leo         11          11         6        11      30
#
#            hemisphere preferredhemisphere
# 0            northern            northern
# 1  northern, southern            southern
# 2  northern, southern  northern, southern
# 3            northern            northern
# 4  northern, southern  northern, southern

# %%
# 유성우 월명이 숫자로 변경되었는지 정보 확인
meteor_showers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5 non-null      str
#  1   radiant              5 non-null      str
#  2   bestmonth            5 non-null      int64
#  3   startmonth           5 non-null      int64
#  4   startday             5 non-null      int64
#  5   endmonth             5 non-null      int64
#  6   endday               5 non-null      int64
#  7   hemisphere           5 non-null      str
#  8   preferredhemisphere  5 non-null      str
# dtypes: int64(5), str(4)
# memory usage: 690.0 bytes

# %%
# 다른 데이터프레임(달의위상, 별자리)도 월명을 숫자로 변환
moon_phases['month'] =moon_phases['month'].map(months)
moon_phases
# Out:
#      month  day      moonphase specialevent
# 0        1    1            NaN          NaN
# 1        1    2  first quarter          NaN
# 2        1    3            NaN          NaN
# 3        1    4            NaN          NaN
# 4        1    5            NaN          NaN
# ..     ...  ...            ...          ...
# 361     12   27            NaN          NaN
# 362     12   28            NaN          NaN
# 363     12   29      full moon          NaN
# 364     12   30            NaN          NaN
# 365     12   31            NaN          NaN
#
# [366 rows x 4 columns]

# %%
moon_phases.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         366 non-null    int64
#  1   day           366 non-null    int64
#  2   moonphase     50 non-null     str
#  3   specialevent  10 non-null     str
# dtypes: int64(2), str(2)
# memory usage: 12.3 KB

# %%
constellations['bestmonth'] = constellations['bestmonth'].map(months)
constellations

#constellations['bestmonth']: constellations라는 표(DataFrame)에서 bestmonth라는 이름의 열을 선택합니다.
#.map(months): 이 부분이 핵심입니다. bestmonth 열에 들어있는 값들을 하나씩 꺼내어 months라는 도구(보통 딕셔너리)에 비추어 보고, 그에 대응하는 값으로 바꿉니다.
#예를 들어, 기존 값이 1이고 months 딕셔너리에 {1: 'January'}라고 되어 있다면, 1을 'January'로 바꿉니다.
#= (대입 연산자): 변환된 새로운 값들을 다시 원래의 bestmonth 열에 덮어씌웁니다.
#constellations: 마지막 줄은 변경이 완료된 전체 표를 화면에 출력해서 확인하겠다는 뜻입니다.
# Out:
#   constellation  bestmonth  latitudestart  latitudeend besttime hemisphere
# 0          Lyra          8             90          -40    21:00   northern
# 1      Aquarius         10             65          -90    21:00   southern
# 2         Orion          1             85          -75    21:00   northern
# 3       Perseus         12             90          -35    21:00   northern
# 4           Leo          4             90           65    21:00   northern

# %%
constellations
# Out:
#   constellation  bestmonth  latitudestart  latitudeend besttime hemisphere
# 0          Lyra          8             90          -40    21:00   northern
# 1      Aquarius         10             65          -90    21:00   southern
# 2         Orion          1             85          -75    21:00   northern
# 3       Perseus         12             90          -35    21:00   northern
# 4           Leo          4             90           65    21:00   northern

# %%
# 달의위상
moon_phases
# Out:
#      month  day      moonphase specialevent
# 0        1    1            NaN          NaN
# 1        1    2  first quarter          NaN
# 2        1    3            NaN          NaN
# 3        1    4            NaN          NaN
# 4        1    5            NaN          NaN
# ..     ...  ...            ...          ...
# 361     12   27            NaN          NaN
# 362     12   28            NaN          NaN
# 363     12   29      full moon          NaN
# 364     12   30            NaN          NaN
# 365     12   31            NaN          NaN
#
# [366 rows x 4 columns]

# %%
moon_phases.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         366 non-null    int64
#  1   day           366 non-null    int64
#  2   moonphase     50 non-null     str
#  3   specialevent  10 non-null     str
# dtypes: int64(2), str(2)
# memory usage: 12.3 KB

# %%
# 별자리
constellations
# Out:
#   constellation  bestmonth  latitudestart  latitudeend besttime hemisphere
# 0          Lyra          8             90          -40    21:00   northern
# 1      Aquarius         10             65          -90    21:00   southern
# 2         Orion          1             85          -75    21:00   northern
# 3       Perseus         12             90          -35    21:00   northern
# 4           Leo          4             90           65    21:00   northern

# %%
constellations.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   constellation  5 non-null      str
#  1   bestmonth      5 non-null      int64
#  2   latitudestart  5 non-null      int64
#  3   latitudeend    5 non-null      int64
#  4   besttime       5 non-null      str
#  5   hemisphere     5 non-null      str
# dtypes: int64(3), str(3)
# memory usage: 464.0 bytes

# %% [markdown]
# ## 일자 정보 Datetime으로 변환(startdate 컬럼 생성)

# %%
meteor_showers
# Out:
#            name   radiant  bestmonth  startmonth  startday  endmonth  endday  \
# 0        Lyrids      Lyra          4           4        21         4      22
# 1  Eta Aquarids  Aquarius          5           4        19         5      28
# 2      Orionids     Orion         10          10         2        11       7
# 3      Perseids   Perseus          8           7        14         8      24
# 4       Leonids       Leo         11          11         6        11      30
#
#            hemisphere preferredhemisphere
# 0            northern            northern
# 1  northern, southern            southern
# 2  northern, southern  northern, southern
# 3            northern            northern
# 4  northern, southern  northern, southern

# %%
# 유성우 데이터프레임의 새로운 컬럼에 일자 정보를 datatime(20240428)으로 변환하여 저장, startdate, enddate
# startdate 컬럼 추가 20200428
# 2020, 4, 21 -> 20200421 -> 2020-04-28
# 2020 * 10000 +meteor_showers['startmonth'] * 100 + meteor_showers['startday']
pd.to_datetime(2020 * 10000 +meteor_showers['startmonth'] * 100 + meteor_showers['startday'], format='%Y%m%d')
# Out:
# 0   2020-04-21
# 1   2020-04-19
# 2   2020-10-02
# 3   2020-07-14
# 4   2020-11-06
# dtype: datetime64[us]

# %%
meteor_showers['startdate'] = pd.to_datetime(2020 * 10000 +meteor_showers['startmonth'] * 100 + meteor_showers['startday'], format='%Y%m%d')
meteor_showers
# Out:
#            name   radiant  bestmonth  startmonth  startday  endmonth  endday  \
# 0        Lyrids      Lyra          4           4        21         4      22
# 1  Eta Aquarids  Aquarius          5           4        19         5      28
# 2      Orionids     Orion         10          10         2        11       7
# 3      Perseids   Perseus          8           7        14         8      24
# 4       Leonids       Leo         11          11         6        11      30
#
#            hemisphere preferredhemisphere  startdate
# 0            northern            northern 2020-04-21
# 1  northern, southern            southern 2020-04-19
# 2  northern, southern  northern, southern 2020-10-02
# 3            northern            northern 2020-07-14
# 4  northern, southern  northern, southern 2020-11-06

# %%
meteor_showers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5 non-null      str
#  1   radiant              5 non-null      str
#  2   bestmonth            5 non-null      int64
#  3   startmonth           5 non-null      int64
#  4   startday             5 non-null      int64
#  5   endmonth             5 non-null      int64
#  6   endday               5 non-null      int64
#  7   hemisphere           5 non-null      str
#  8   preferredhemisphere  5 non-null      str
#  9   startdate            5 non-null      datetime64[us]
# dtypes: datetime64[us](1), int64(5), str(4)
# memory usage: 730.0 bytes

# %%
# 유성우 데이터프레임의 새로운 컬럼에 일자 정보를 datatime(20240428)으로 변환하여 저장, startdate, enddate
# enddate 컬럼 추가
meteor_showers['enddate'] = pd.to_datetime(2020 * 10000 +meteor_showers['endmonth'] * 100 + meteor_showers['endday'], format='%Y%m%d')
meteor_showers
# Out:
#            name   radiant  bestmonth  startmonth  startday  endmonth  endday  \
# 0        Lyrids      Lyra          4           4        21         4      22
# 1  Eta Aquarids  Aquarius          5           4        19         5      28
# 2      Orionids     Orion         10          10         2        11       7
# 3      Perseids   Perseus          8           7        14         8      24
# 4       Leonids       Leo         11          11         6        11      30
#
#            hemisphere preferredhemisphere  startdate    enddate
# 0            northern            northern 2020-04-21 2020-04-22
# 1  northern, southern            southern 2020-04-19 2020-05-28
# 2  northern, southern  northern, southern 2020-10-02 2020-11-07
# 3            northern            northern 2020-07-14 2020-08-24
# 4  northern, southern  northern, southern 2020-11-06 2020-11-30

# %%
moon_phases
# Out:
#      month  day      moonphase specialevent
# 0        1    1            NaN          NaN
# 1        1    2  first quarter          NaN
# 2        1    3            NaN          NaN
# 3        1    4            NaN          NaN
# 4        1    5            NaN          NaN
# ..     ...  ...            ...          ...
# 361     12   27            NaN          NaN
# 362     12   28            NaN          NaN
# 363     12   29      full moon          NaN
# 364     12   30            NaN          NaN
# 365     12   31            NaN          NaN
#
# [366 rows x 4 columns]

# %%
# moon_phases 데이터 프레임에 일자 정보를 datatime으로 변환하여 date컬럼 추가 20200428
moon_phases['date'] = pd.to_datetime(2020 * 10000 +moon_phases['month'] * 100 + moon_phases['day'], format='%Y%m%d')
moon_phases
# Out:
#      month  day      moonphase specialevent       date
# 0        1    1            NaN          NaN 2020-01-01
# 1        1    2  first quarter          NaN 2020-01-02
# 2        1    3            NaN          NaN 2020-01-03
# 3        1    4            NaN          NaN 2020-01-04
# 4        1    5            NaN          NaN 2020-01-05
# ..     ...  ...            ...          ...        ...
# 361     12   27            NaN          NaN 2020-12-27
# 362     12   28            NaN          NaN 2020-12-28
# 363     12   29      full moon          NaN 2020-12-29
# 364     12   30            NaN          NaN 2020-12-30
# 365     12   31            NaN          NaN 2020-12-31
#
# [366 rows x 5 columns]

# %%
moon_phases.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         366 non-null    int64
#  1   day           366 non-null    int64
#  2   moonphase     50 non-null     str
#  3   specialevent  10 non-null     str
#  4   date          366 non-null    datetime64[us]
# dtypes: datetime64[us](1), int64(2), str(2)
# memory usage: 15.2 KB

# %% [markdown]
# ## 달의 위상 데이터를 숫자로 변환

# %%
moon_phases['moonphase'].unique()
# Out:
# <ArrowStringArray>
# [nan, 'first quarter', 'full moon', 'third quarter', 'new moon']
# Length: 5, dtype: str

# %%
# 달의 위상 데이터를 숫자로 변환하기
phase = {'new moon': 0, 'first quarter': 0.5, 'third quarter': 0.5, 'full moon': 1}

# %%
# 달의위상 데이터프레임에 phases데이터를 이용하여 백분율 컬럼(percentage) 새롭게 추가하기
moon_phases['percentage'] = moon_phases['moonphase'].map(phase)
moon_phases
# Out:
#      month  day      moonphase specialevent       date  percentage
# 0        1    1            NaN          NaN 2020-01-01         NaN
# 1        1    2  first quarter          NaN 2020-01-02         0.5
# 2        1    3            NaN          NaN 2020-01-03         NaN
# 3        1    4            NaN          NaN 2020-01-04         NaN
# 4        1    5            NaN          NaN 2020-01-05         NaN
# ..     ...  ...            ...          ...        ...         ...
# 361     12   27            NaN          NaN 2020-12-27         NaN
# 362     12   28            NaN          NaN 2020-12-28         NaN
# 363     12   29      full moon          NaN 2020-12-29         1.0
# 364     12   30            NaN          NaN 2020-12-30         NaN
# 365     12   31            NaN          NaN 2020-12-31         NaN
#
# [366 rows x 6 columns]

# %%
moon_phases.sample(10)
# Out:
#      month  day      moonphase specialevent       date  percentage
# 323     11   19            NaN          NaN 2020-11-19         NaN
# 153      6    2            NaN          NaN 2020-06-02         NaN
# 266      9   23  first quarter          NaN 2020-09-23         0.5
# 125      5    5            NaN          NaN 2020-05-05         NaN
# 346     12   12            NaN          NaN 2020-12-12         NaN
# 5        1    6            NaN          NaN 2020-01-06         NaN
# 257      9   14            NaN          NaN 2020-09-14         NaN
# 201      7   20       new moon          NaN 2020-07-20         0.0
# 265      9   22            NaN          NaN 2020-09-22         NaN
# 254      9   11            NaN          NaN 2020-09-11         NaN

# %% [markdown]
# ## 불필요한 컬럼 삭제

# %%
# 각 데이터 프레임에서 불필요한 컬럼 삭제하기

# %%
constellations = constellations.drop(columns=['besttime'])
constellations
# Out:
#   constellation  bestmonth  latitudestart  latitudeend hemisphere
# 0          Lyra          8             90          -40   northern
# 1      Aquarius         10             65          -90   southern
# 2         Orion          1             85          -75   northern
# 3       Perseus         12             90          -35   northern
# 4           Leo          4             90           65   northern

# %%
meteor_showers = meteor_showers.drop(columns=['startmonth', 'startday','endmonth', 'endday', 'preferredhemisphere' ])
meteor_showers
# Out:
#            name   radiant  bestmonth          hemisphere  startdate    enddate
# 0        Lyrids      Lyra          4            northern 2020-04-21 2020-04-22
# 1  Eta Aquarids  Aquarius          5  northern, southern 2020-04-19 2020-05-28
# 2      Orionids     Orion         10  northern, southern 2020-10-02 2020-11-07
# 3      Perseids   Perseus          8            northern 2020-07-14 2020-08-24
# 4       Leonids       Leo         11  northern, southern 2020-11-06 2020-11-30

# %%
moon_phases = moon_phases.drop(columns=['month', 'day', 'moonphase','specialevent' ])
moon_phases
# Out:
#           date  percentage
# 0   2020-01-01         NaN
# 1   2020-01-02         0.5
# 2   2020-01-03         NaN
# 3   2020-01-04         NaN
# 4   2020-01-05         NaN
# ..         ...         ...
# 361 2020-12-27         NaN
# 362 2020-12-28         NaN
# 363 2020-12-29         1.0
# 364 2020-12-30         NaN
# 365 2020-12-31         NaN
#
# [366 rows x 2 columns]

# %%
constellations
# Out:
#   constellation  bestmonth  latitudestart  latitudeend hemisphere
# 0          Lyra          8             90          -40   northern
# 1      Aquarius         10             65          -90   southern
# 2         Orion          1             85          -75   northern
# 3       Perseus         12             90          -35   northern
# 4           Leo          4             90           65   northern

# %% [markdown]
# ## 달의 위상 누락값 처리

# %%
# 달의위상 데이터 프레임에서 percentage 컬럼의 결측치 처리하기
moon_phases['percentage'] = moon_phases['percentage'].ffill().fillna(0)
moon_phases
# Out:
#           date  percentage
# 0   2020-01-01         0.0
# 1   2020-01-02         0.5
# 2   2020-01-03         0.5
# 3   2020-01-04         0.5
# 4   2020-01-05         0.5
# ..         ...         ...
# 361 2020-12-27         0.5
# 362 2020-12-28         0.5
# 363 2020-12-29         1.0
# 364 2020-12-30         1.0
# 365 2020-12-31         1.0
#
# [366 rows x 2 columns]

# %%
cities
# Out:
#                         city  latitude               country
# 0                  Abu Dhabi     24.47  United Arab Emirates
# 1                      Abuja      9.07               Nigeria
# 2                      Accra      5.55                 Ghana
# 3                  Adamstown    -25.07      Pitcairn Islands
# 4                Addis Ababa      9.02              Ethiopia
# ..                       ...       ...                   ...
# 251  Abidjan(former capital)      6.82           Ivory Coast
# 252                  Yaounde      3.87              Cameroon
# 253          Yaren(de facto)     -0.53                 Nauru
# 254                  Yerevan     40.18               Armenia
# 255                   Zagreb     45.82               Croatia
#
# [256 rows x 3 columns]

# %% [markdown]
# # 데이터 분석

# %%
#도시의 위도를 확인
#위도를 사용해서 해당 도시에 표시되는 별자리 확인
#별자리를 사용해서 해당 도시에서 볼수 있는 유성우 확인
#유성우를 사용해서 해당 유성우를 볼 수 있는 날짜 확인
#날짜를 사용해서 달의 위상값이 가장 작은 최적 날짜 확인

#마지막으로 사용자에게 기분좋은 문구 반환
# cities -> constellations -> meteor_showers -> moon_phases
# 위도정보          별자리 -> 유성우       관측가능기간     가장 어더운날

# %% [markdown]
# ## 위도 조회

# %%
#지정된 도시에서 각 유성우를 볼 수 있는 가능성이 높은 날짜를 예측하려고 합니다.

# %% [markdown]
# ### 도시명 입력 후 위도 반환

# %%
# 도시 데이터프레임에서 검색한 열(검색한 도시의 위도)만 가져오기
# dframe.loc[조건, 가져올 컬럼 이름]
cities.loc[cities['city'] == 'Abu Dhabi', ['city', 'latitude']]
# 결과: Abu Dhabi의 위도는 24.47입니다.
# Out:
#         city  latitude
# 0  Abu Dhabi     24.47

# %%
# 도시명을 입력하면 위도를 반환하는 함수 만들기
def predict_best_meteor_shower_viewing(city):
    latitude = cities.loc[cities['city'] == city, 'latitude'].iloc[0]
    return latitude

# %%
print(predict_best_meteor_shower_viewing('Abu Dhabi'))
# Out:
# 24.47

# %%
print(predict_best_meteor_shower_viewing('Seoul'))
# Out:
# 37.55

# %% [markdown]
# ## 특정 위도에서 볼 수 있는 별자리 조회

# %%
constellations
# Out:
#   constellation  bestmonth  latitudestart  latitudeend hemisphere
# 0          Lyra          8             90          -40   northern
# 1      Aquarius         10             65          -90   southern
# 2         Orion          1             85          -75   northern
# 3       Perseus         12             90          -35   northern
# 4           Leo          4             90           65   northern

# %%
# 24.47 혹은 37.55 위도값으로 관측 가능한 별자리 리스트를 반환
# ['Lyra','Aquarius','Orion', 'Perseus']

latitude = 37.55
list(constellations.loc[(constellations['latitudestart'] >= 37.55) & (37.55 >= constellations['latitudeend']),'constellation'])
# Out:
# ['Lyra', 'Aquarius', 'Orion', 'Perseus']

# %%
# 도시명을 입력하면 위도와 별자리 리스트를 반환하는 함수 만들기

def predict_best_meteor_shower_viewing(city):
    
    meteor_shower_string =''


    if city not in cities['city'].values:
        meteor_shower_string = f'아쉽지만{city}에는 별자리 서비스가 제공되지 않습니다!.'
        return meteor_shower_string
    
    latitude = cities.loc[cities['city'] == city, 'latitude'].iloc[0]

    constellations_list = constellations.loc[(constellations['latitudestart'] >= latitude) & (latitude >= constellations['latitudeend']), 'constellation'].to_list()

    return latitude, constellations_list, meteor_shower_string

# %%
predict_best_meteor_shower_viewing('Busan')
# Out:
# '아쉽지만Busan에는 별자리 서비스가 제공되지 않습니다!.'

# %%
# 뉴질랜드 웰링턴으로 확인
predict_best_meteor_shower_viewing('Wellington')
# Out:
# (np.float64(-41.28), ['Aquarius', 'Orion'], '')

# %%
predict_best_meteor_shower_viewing('Seoul')
# Out:
# (np.float64(37.55), ['Lyra', 'Aquarius', 'Orion', 'Perseus'], '')

# %% [markdown]
# ## 문자 안내 출력

# %%
wellington = predict_best_meteor_shower_viewing('Wellington')
wellington
# Out:
# (np.float64(-41.28), ['Aquarius', 'Orion'], '')

# %% [markdown]
# ## 유성우 관측 기간 조회(선택한 도시에서 관측 가능한 별자리 추출)

# %%
meteor_showers.head()
# Out:
#            name   radiant  bestmonth          hemisphere  startdate    enddate
# 0        Lyrids      Lyra          4            northern 2020-04-21 2020-04-22
# 1  Eta Aquarids  Aquarius          5  northern, southern 2020-04-19 2020-05-28
# 2      Orionids     Orion         10  northern, southern 2020-10-02 2020-11-07
# 3      Perseids   Perseus          8            northern 2020-07-14 2020-08-24
# 4       Leonids       Leo         11  northern, southern 2020-11-06 2020-11-30

# %%
meteor_showers.loc[meteor_showers['radiant'] == 'Orion','startdate'].iloc[0]
meteor_showers.loc[meteor_showers['radiant'] == 'Orion','enddate'].iloc[0]
meteor_showers.loc[meteor_showers['radiant'] == 'Orion','name'].iloc[0]
# Out:
# 'Orionids'

# %%
for i in wellington[1]:
    meteor_shower = meteor_showers.loc[meteor_showers['radiant'] == i,'name'].iloc[0]
    meteor_shower_startdate = meteor_showers.loc[meteor_showers['radiant'] == i,'startdate'].iloc[0]
    meteor_shower_enddate = meteor_showers.loc[meteor_showers['radiant'] == i,'enddate'].iloc[0]

print(meteor_shower, meteor_shower_startdate, meteor_shower_enddate)
# Out:
# Orionids 2020-10-02 00:00:00 2020-11-07 00:00:00

# %%
wellington[1]
# Out:
# ['Aquarius', 'Orion']

# %%
moon_phases[(moon_phases['date'] >= meteor_shower_startdate) & (moon_phases['date'] <= meteor_shower_enddate)]
# Out:
#           date  percentage
# 275 2020-10-02         1.0
# 276 2020-10-03         1.0
# 277 2020-10-04         1.0
# 278 2020-10-05         1.0
# 279 2020-10-06         1.0
# 280 2020-10-07         1.0
# 281 2020-10-08         1.0
# 282 2020-10-09         0.5
# 283 2020-10-10         0.5
# 284 2020-10-11         0.5
# 285 2020-10-12         0.5
# 286 2020-10-13         0.5
# 287 2020-10-14         0.5
# 288 2020-10-15         0.5
# 289 2020-10-16         0.0
# 290 2020-10-17         0.0
# 291 2020-10-18         0.0
# 292 2020-10-19         0.0
# 293 2020-10-20         0.0
# 294 2020-10-21         0.0
# 295 2020-10-22         0.0
# 296 2020-10-23         0.5
# 297 2020-10-24         0.5
# 298 2020-10-25         0.5
# 299 2020-10-26         0.5
# 300 2020-10-27         0.5
# 301 2020-10-28         0.5
# 302 2020-10-29         0.5
# 303 2020-10-30         0.5
# 304 2020-10-31         1.0
# 305 2020-11-01         1.0
# 306 2020-11-02         1.0
# 307 2020-11-03         1.0
# ...

# %% [markdown]
# ## 달의 위상 최저치 추출

# %%
달 위상의 최소값(달에서 반사되는 빛의 최소량)을 찾을 수 있습니다. 이 예측 함수에서는 첫 번째 날짜만 확인합니다.
# Out:
#   Cell In[167], line 1
#     달 위상의 최소값(달에서 반사되는 빛의 최소량)을 찾을 수 있습니다. 이 예측 함수에서는 첫 번째 날짜만 확인합니다.
#       ^
# SyntaxError: invalid syntax

# %%
moon_phases_list = moon_phases[(moon_phases['date'] >= meteor_shower_startdate) & (moon_phases['date'] <= meteor_shower_enddate)]
moon_phases_list

# %%
moon_phases[(moon_phases['date'] >= meteor_shower_startdate) & ()]

# %%
# 가장 어두운 날 찾기
best_moon_date = moon_phases_list.loc[moon_phases_list['percentage'].idxmin(), 'date'] # 가장 백분율이 적은 행 인덱스 반환
best_moon_date

# %%
best_moon_date.to_pydatetime().strftime('%Y년 %m월 %d일')

# %%
constellations

# %%
meteor_showers

# %% [markdown]
# ## 최적의 유성우 관측일

# %%
# 도시명을 입력하면 관측가능한 유성우에 대한 정보를 알려주는 함수 작성하기

def predict_best_meteor_shower_viewing(city):
    
    meteor_shower_string = ''

    if city not in cities['city'].values:
        meteor_shower_string = f'아쉽지만 {city}에는 별자리 서비스가 제공되지 않습니다!.'
        return meteor_shower_string

    latitude = cities.loc[cities['city'] == city, 'latitude'].iloc[0]

    constellations_list = constellations.loc[(constellations['latitudestart'] >= latitude) & (latitude >= constellations['latitudeend']), 'constellation'].to_list()

    meteor_shower_string = f'{city} 에서는 아래의 유성우들을 관측할 수 있습니다.\n'

    for i in constellations_list:
        meteor_shower = meteor_showers.loc[meteor_showers['radiant'] == i, 'name'].iloc[0]
        meteor_shower_startdate = meteor_showers.loc[meteor_showers['radiant'] == i, 'startdate'].iloc[0]
        meteor_shower_enddate = meteor_showers.loc[meteor_showers['radiant'] == i, 'enddate'].iloc[0]
        moon_phases_list = moon_phases[(moon_phases['date'] >= meteor_shower_startdate) & (moon_phases['date'] <= meteor_shower_enddate)]
        best_moon_date = moon_phases_list.loc[moon_phases_list['percentage'].idxmin(), 'date']
        best_moon_date_str = best_moon_date.to_pydatetime().strftime('%Y년 %m월 %d일')

        meteor_shower_string += f"\n{meteor_shower}는 {best_moon_date_str}에 가장 잘 볼 수 있습니다."

    return meteor_shower_string

# %%
print(predict_best_meteor_shower_viewing('New York'))

# %%
print(predict_best_meteor_shower_viewing('Wellington'))

# %%
print(predict_best_meteor_shower_viewing('Seoul'))

# %%
print(predict_best_meteor_shower_viewing('Abu Dhabi'))

# %% [markdown]
# # 항아 유성우 데이터 추가

# %%
# 항아 유성우 데이터 추가하기
change_meteor_shower = {'name' : "Chang\'e", 'radiant' : 'Draco', 'bestmonth' : 'october', 'startmonth': 'october', 'startday' : 1,
                        'endmonth' : 'october', 'endday' : 31, 'hemisphere' : 'northern', 'preferredhemisphere' : 'northern' }
change_meteor_shower_df = pd.DataFrame(change_meteor_shower,index = [0])
change_meteor_shower_df

# %%
# meteorshowers.csv 파일 읽어와서 new_meteor_showers 변수에 저장
new_meteor_showers = pd.read_csv('data/meteorshowers.csv')
new_meteor_showers

# %%
# new_meteor_showers 데이터프레임에 change_meteor_shower_df 데이터프레임 추가하기 concat
new_meteor_showers = pd.concat([new_meteor_showers, change_meteor_shower_df], ignore_index=True)
new_meteor_showers

# %%
# Chang'e 유성우에 대해 Draconids 유성우가 10월 초에 발생할 가능성이 높은 용자리를 선택합니다. 이 유성우를 가상 유성우의 참조로 사용
# 용자리 항목 추가하기기
draco_constellation = {'constellation' : 'Draco', 'bestmonth' : 'july', 'latitudestart' : 90, 'latitudeend' : -15, 'besttime' :2100, 'hemisphere' : 'northern'}
draco_constellation_df = pd.DataFrame(draco_constellation, index = [0])
draco_constellation_df

# %%
# 별자리 파일 읽어와서 new_constellations에 저장하기
new_constellations = pd.read_csv('data/constellations.csv')
new_constellations

# %%
# new_constellations 데이터프레임에 draco_constellation_df 추가하기 concat
new_constellations =  pd.concat([new_constellations, draco_constellation_df], ignore_index=True)# Todo Here
new_constellations

# %%
# new_meteor_showers 데이터프레임 월명 매핑
new_meteor_showers['startmonth'] = new_meteor_showers['startmonth'].map(months)
new_meteor_showers['bestmonth'] = new_meteor_showers['bestmonth'].map(months)
new_meteor_showers['endmonth'] = new_meteor_showers['endmonth'].map(months)
new_meteor_showers

# %%
# new_constellations 데이터프레임 월명 매핑
new_constellations['bestmonth'] = new_constellations['bestmonth'].map(months)
new_constellations

# %%
# new_meteor_showers 날짜형식 바꿔서 새로운 컬럼으로 추가 startdate, enddate
new_meteor_showers['startdate'] = pd.to_datetime(2020 * 10000 + 
                                             new_meteor_showers['startmonth'] * 100 + 
                                             new_meteor_showers['startday'],
                                             format = '%Y%m%d')
new_meteor_showers['enddate'] = pd.to_datetime(2020 * 10000 + 
                                             new_meteor_showers['endmonth'] * 100 + 
                                             new_meteor_showers['endday'],
                                             format = '%Y%m%d')

new_meteor_showers

# %%
# 도시명을 입력히면 위도를 반환하는 함수
def predict_best_meteor_shower_viewing(city):


    return meteor_shower_string

# %%
print(predict_best_meteor_shower_viewing('Beijing'))
